# %%
import pandas as pd
from model import Model
from api import Features

# %%
model_path = 'cbc.pkl'

# %%
df = pd.read_csv('mfeatures.csv')
model = Model(model_path)

# %%
df_test = df[df['target'].isna()].fillna(-999999)
df_test = df_test.rename(columns={'sk_id_curr': 'SK_ID_CURR'})

# %%
df_test['result'] = df_test.drop(columns=['SK_ID_CURR', 'target']).apply(
    lambda x: model.get_scoring_result(
        Features(
        count_doc=x['count_doc'],
        age=x['age'],
        year_change_doc=x['year_change_doc'],
        diff_age_change_doc=x['diff_age_change_doc'],
        fraq_credit_income=x['fraq_credit_income'],
        child_per_adult=x['child_per_adult'],
        income_per_child=x['income_per_child'],
        income_per_adult=x['income_per_adult'],
        interest_rate=x['interest_rate'],
        weighted_ext_scores=x['weighted_ext_scores'],
        diff_amt_client_amt_group=x['diff_amt_client_amt_group'],
        count_open_credits=x['count_open_credits'],
        ratio_open_credits=x['ratio_open_credits'],
        month_close=x['month_close'],
        month_active=x['month_active'],
        max_amt_overdue=x['max_amt_overdue'],
        min_amt_overdue=x['min_amt_overdue'],
        ratio_active_credits=x['ratio_active_credits'],
        count_Another_type_of_loan=x['count_Another_type_of_loan'],
        count_Car_loan=x['count_Car_loan'],
        count_Cash_loan_nonearmarked=x['count_Cash_loan_nonearmarked'],
        count_Consumer_credit=x['count_Consumer_credit'],
        count_Interbank_credit=x['count_Interbank_credit'],
        count_Loan_for_business_development=x['count_Loan_for_business_development'],
        count_Loan_for_purchase_of_shares_margin_lending=x['count_Loan_for_purchase_of_shares_margin_lending'],
        count_Loan_for_the_purchase_of_equipment=x['count_Loan_for_the_purchase_of_equipment'],
        count_Loan_for_working_capital_replenishment=x['count_Loan_for_working_capital_replenishment'],
        count_Microloan=x['count_Microloan'],
        count_Mobile_operator_loan=x['count_Mobile_operator_loan'],
        count_Mortgage=x['count_Mortgage'],
        count_Real_estate_loan=x['count_Real_estate_loan'],
        count_Unknown_type_of_loan=x['count_Unknown_type_of_loan'],
        count_overdue_Another_type_of_loan=x['count_overdue_Another_type_of_loan'],
        count_overdue_Car_loan=x['count_overdue_Car_loan'],
        count_overdue_Consumer_credit=x['count_overdue_Consumer_credit'],
        count_overdue_Credit_card=x['count_overdue_Credit_card'],
        count_overdue_Loan_for_business_development=x['count_overdue_Loan_for_business_development'],
        count_overdue_Loan_for_working_capital_replenishment=x['count_overdue_Loan_for_working_capital_replenishment'],
        count_overdue_Microloan=x['count_overdue_Microloan'],
        count_overdue_Mortgage=x['count_overdue_Mortgage'],
        count_closed_Another_type_of_loan=x['count_closed_Another_type_of_loan'],
        count_closed_Car_loan=x['count_closed_Car_loan'],
        count_closed_Cash_loan_nonearmarked=x['count_closed_Cash_loan_nonearmarked'],
        count_closed_Consumer_credit=x['count_closed_Consumer_credit'],
        count_closed_Credit_card=x['count_closed_Credit_card'],
        count_closed_Interbank_credit=x['count_closed_Interbank_credit'],
        count_closed_Loan_for_business_development=x['count_closed_Loan_for_business_development'],
        count_closed_Loan_for_purchase_of_shares_margin_lending=x['count_closed_Loan_for_purchase_of_shares_margin_lending'],
        count_closed_Loan_for_the_purchase_of_equipment=x['count_closed_Loan_for_the_purchase_of_equipment'],
        count_closed_Loan_for_working_capital_replenishment=x['count_closed_Loan_for_working_capital_replenishment'],
        count_closed_Microloan=x['count_closed_Microloan'],
        count_closed_Mortgage=x['count_closed_Mortgage'],
        count_closed_Real_estate_loan=x['count_closed_Real_estate_loan'],
        count_closed_Unknown_type_of_loan=x['count_closed_Unknown_type_of_loan'],
        amt_annuity_max=x['amt_annuity_max'],
        amt_annuity_min=x['amt_annuity_min'],
        amt_annuity_mean=x['amt_annuity_mean'],
        amt_annuity_median=x['amt_annuity_median'],
        amt_annuity_sum=x['amt_annuity_sum'],
        amt_annuity_std=x['amt_annuity_std'],
        amt_application_max=x['amt_application_max'],
        amt_application_min=x['amt_application_min'],
        amt_application_mean=x['amt_application_mean'],
        amt_application_median=x['amt_application_median'],
        amt_credit_min=x['amt_credit_min'],
        amt_credit_mean=x['amt_credit_mean'],
        amt_credit_median=x['amt_credit_median'],
        amt_down_payment_max=x['amt_down_payment_max'],
        amt_down_payment_min=x['amt_down_payment_min'],
        amt_down_payment_mean=x['amt_down_payment_mean'],
        amt_down_payment_median=x['amt_down_payment_median'],
        amt_down_payment_sum=x['amt_down_payment_sum'],
        amt_down_payment_std=x['amt_down_payment_std'],
        amt_goods_price_max=x['amt_goods_price_max'],
        amt_goods_price_min=x['amt_goods_price_min'],
        amt_goods_price_mean=x['amt_goods_price_mean'],
        amt_goods_price_median=x['amt_goods_price_median'],
        flag_last_appl_per_contract_sum=x['flag_last_appl_per_contract_sum'],
        nflag_last_appl_in_day_sum=x['nflag_last_appl_in_day_sum'],
        nflag_insured_on_approval_sum=x['nflag_insured_on_approval_sum'],
        rate_down_payment_mean=x['rate_down_payment_mean'],
        rate_down_payment_median=x['rate_down_payment_median'],
        days_first_drawing_min=x['days_first_drawing_min'],
        days_first_drawing_max=x['days_first_drawing_max'],
        days_first_due_min=x['days_first_due_min'],
        days_first_due_max=x['days_first_due_max'],
        days_last_due_min=x['days_last_due_min'],
        days_last_due_max=x['days_last_due_max'],
        cnt_instalment_future_mean_all=x['cnt_instalment_future_mean_all'],
        cnt_instalment_future_sum_all=x['cnt_instalment_future_sum_all'],
        cnt_instalment_mean_all=x['cnt_instalment_mean_all'],
        cnt_instalment_sum_all=x['cnt_instalment_sum_all'],
        sk_dpd_mean_all=x['sk_dpd_mean_all'],
        sk_dpd_sum_all=x['sk_dpd_sum_all'],
        sk_dpd_def_mean_all=x['sk_dpd_def_mean_all'],
        sk_dpd_def_sum_all=x['sk_dpd_def_sum_all'],
        cnt_instalment_future_mean_3years=x['cnt_instalment_future_mean_3years'],
        cnt_instalment_future_sum_3years=x['cnt_instalment_future_sum_3years'],
        cnt_instalment_mean_3years=x['cnt_instalment_mean_3years'],
        cnt_instalment_sum_3years=x['cnt_instalment_sum_3years'],
        sk_dpd_mean_3years=x['sk_dpd_mean_3years'],
        sk_dpd_sum_3years=x['sk_dpd_sum_3years'],
        sk_dpd_def_mean_3years=x['sk_dpd_def_mean_3years'],
        sk_dpd_def_sum_3years=x['sk_dpd_def_sum_3years'],
        num_instalment_number=x['num_instalment_number'],
        flag_overdue=x['flag_overdue'],
        flag_overdue_amt=x['flag_overdue_amt'],
        amt_balance_max=x['amt_balance_max'],
        amt_balance_min=x['amt_balance_min'],
        amt_balance_mean=x['amt_balance_mean'],
        amt_balance_median=x['amt_balance_median'],
        amt_balance_sum=x['amt_balance_sum'],
        amt_balance_var=x['amt_balance_var'],
        amt_balance_std=x['amt_balance_std'],
        amt_credit_limit_actual_max=x['amt_credit_limit_actual_max'],
        amt_credit_limit_actual_min=x['amt_credit_limit_actual_min'],
        amt_credit_limit_actual_mean=x['amt_credit_limit_actual_mean'],
        amt_credit_limit_actual_median=x['amt_credit_limit_actual_median'],
        amt_credit_limit_actual_sum=x['amt_credit_limit_actual_sum'],
        amt_credit_limit_actual_var=x['amt_credit_limit_actual_var'],
        amt_credit_limit_actual_std=x['amt_credit_limit_actual_std'],
        amt_drawings_atm_current_max=x['amt_drawings_atm_current_max'],
        amt_drawings_atm_current_min=x['amt_drawings_atm_current_min'],
        amt_drawings_atm_current_mean=x['amt_drawings_atm_current_mean'],
        amt_drawings_atm_current_median=x['amt_drawings_atm_current_median'],
        amt_drawings_atm_current_sum=x['amt_drawings_atm_current_sum'],
        amt_drawings_atm_current_var=x['amt_drawings_atm_current_var'],
        amt_drawings_atm_current_std=x['amt_drawings_atm_current_std'],
        amt_drawings_current_max=x['amt_drawings_current_max'],
        amt_drawings_current_min=x['amt_drawings_current_min'],
        amt_drawings_current_mean=x['amt_drawings_current_mean'],
        amt_drawings_current_median=x['amt_drawings_current_median'],
        amt_drawings_current_sum=x['amt_drawings_current_sum'],
        amt_drawings_current_var=x['amt_drawings_current_var'],
        amt_drawings_current_std=x['amt_drawings_current_std'],
        amt_drawings_other_current_max=x['amt_drawings_other_current_max'],
        amt_drawings_other_current_min=x['amt_drawings_other_current_min'],
        amt_drawings_other_current_mean=x['amt_drawings_other_current_mean'],
        amt_drawings_other_current_median=x['amt_drawings_other_current_median'],
        amt_drawings_other_current_sum=x['amt_drawings_other_current_sum'],
        amt_drawings_other_current_var=x['amt_drawings_other_current_var'],
        amt_drawings_other_current_std=x['amt_drawings_other_current_std'],
        amt_drawings_pos_current_max=x['amt_drawings_pos_current_max'],
        amt_drawings_pos_current_min=x['amt_drawings_pos_current_min'],
        amt_drawings_pos_current_mean=x['amt_drawings_pos_current_mean'],
        amt_drawings_pos_current_median=x['amt_drawings_pos_current_median'],
        amt_drawings_pos_current_sum=x['amt_drawings_pos_current_sum'],
        amt_drawings_pos_current_var=x['amt_drawings_pos_current_var'],
        amt_drawings_pos_current_std=x['amt_drawings_pos_current_std'],
        amt_inst_min_regularity_max=x['amt_inst_min_regularity_max'],
        amt_inst_min_regularity_min=x['amt_inst_min_regularity_min'],
        amt_inst_min_regularity_mean=x['amt_inst_min_regularity_mean'],
        amt_inst_min_regularity_median=x['amt_inst_min_regularity_median'],
        amt_inst_min_regularity_sum=x['amt_inst_min_regularity_sum'],
        amt_inst_min_regularity_var=x['amt_inst_min_regularity_var'],
        amt_inst_min_regularity_std=x['amt_inst_min_regularity_std'],
        amt_payment_current_max=x['amt_payment_current_max'],
        amt_payment_current_min=x['amt_payment_current_min'],
        amt_payment_current_mean=x['amt_payment_current_mean'],
        amt_payment_current_median=x['amt_payment_current_median'],
        amt_payment_current_sum=x['amt_payment_current_sum'],
        amt_payment_current_var=x['amt_payment_current_var'],
        amt_payment_current_std=x['amt_payment_current_std'],
        amt_payment_total_current_max=x['amt_payment_total_current_max'],
        amt_payment_total_current_min=x['amt_payment_total_current_min'],
        amt_payment_total_current_mean=x['amt_payment_total_current_mean'],
        amt_payment_total_current_median=x['amt_payment_total_current_median'],
        amt_payment_total_current_sum=x['amt_payment_total_current_sum'],
        amt_payment_total_current_var=x['amt_payment_total_current_var'],
        amt_payment_total_current_std=x['amt_payment_total_current_std'],
        amt_receivable_principal_max=x['amt_receivable_principal_max'],
        amt_receivable_principal_min=x['amt_receivable_principal_min'],
        amt_receivable_principal_mean=x['amt_receivable_principal_mean'],
        amt_receivable_principal_median=x['amt_receivable_principal_median'],
        amt_receivable_principal_sum=x['amt_receivable_principal_sum'],
        amt_receivable_principal_var=x['amt_receivable_principal_var'],
        amt_receivable_principal_std=x['amt_receivable_principal_std'],
        amt_recivable_max=x['amt_recivable_max'],
        amt_recivable_min=x['amt_recivable_min'],
        amt_recivable_mean=x['amt_recivable_mean'],
        amt_recivable_median=x['amt_recivable_median'],
        amt_recivable_sum=x['amt_recivable_sum'],
        amt_recivable_var=x['amt_recivable_var'],
        amt_recivable_std=x['amt_recivable_std'],
        amt_total_receivable_max=x['amt_total_receivable_max'],
        amt_total_receivable_min=x['amt_total_receivable_min'],
        amt_total_receivable_mean=x['amt_total_receivable_mean'],
        amt_total_receivable_median=x['amt_total_receivable_median'],
        amt_total_receivable_sum=x['amt_total_receivable_sum'],
        amt_total_receivable_var=x['amt_total_receivable_var'],
        amt_total_receivable_std=x['amt_total_receivable_std'],
        cnt_drawings_atm_current_max=x['cnt_drawings_atm_current_max'],
        cnt_drawings_atm_current_min=x['cnt_drawings_atm_current_min'],
        cnt_drawings_atm_current_mean=x['cnt_drawings_atm_current_mean'],
        cnt_drawings_atm_current_median=x['cnt_drawings_atm_current_median'],
        cnt_drawings_atm_current_sum=x['cnt_drawings_atm_current_sum'],
        cnt_drawings_atm_current_var=x['cnt_drawings_atm_current_var'],
        cnt_drawings_atm_current_std=x['cnt_drawings_atm_current_std'],
        cnt_drawings_current_max=x['cnt_drawings_current_max'],
        cnt_drawings_current_min=x['cnt_drawings_current_min'],
        cnt_drawings_current_mean=x['cnt_drawings_current_mean'],
        cnt_drawings_current_median=x['cnt_drawings_current_median'],
        cnt_drawings_current_sum=x['cnt_drawings_current_sum'],
        cnt_drawings_current_var=x['cnt_drawings_current_var'],
        cnt_drawings_current_std=x['cnt_drawings_current_std'],
        cnt_drawings_other_current_max=x['cnt_drawings_other_current_max'],
        cnt_drawings_other_current_min=x['cnt_drawings_other_current_min'],
        cnt_drawings_other_current_mean=x['cnt_drawings_other_current_mean'],
        cnt_drawings_other_current_median=x['cnt_drawings_other_current_median'],
        cnt_drawings_other_current_sum=x['cnt_drawings_other_current_sum'],
        cnt_drawings_other_current_var=x['cnt_drawings_other_current_var'],
        cnt_drawings_other_current_std=x['cnt_drawings_other_current_std'],
        cnt_drawings_pos_current_max=x['cnt_drawings_pos_current_max'],
        cnt_drawings_pos_current_min=x['cnt_drawings_pos_current_min'],
        cnt_drawings_pos_current_mean=x['cnt_drawings_pos_current_mean'],
        cnt_drawings_pos_current_median=x['cnt_drawings_pos_current_median'],
        cnt_drawings_pos_current_sum=x['cnt_drawings_pos_current_sum'],
        cnt_drawings_pos_current_var=x['cnt_drawings_pos_current_var'],
        cnt_drawings_pos_current_std=x['cnt_drawings_pos_current_std'],
        cnt_instalment_mature_cum_max=x['cnt_instalment_mature_cum_max'],
        cnt_instalment_mature_cum_min=x['cnt_instalment_mature_cum_min'],
        cnt_instalment_mature_cum_mean=x['cnt_instalment_mature_cum_mean'],
        cnt_instalment_mature_cum_median=x['cnt_instalment_mature_cum_median'],
        cnt_instalment_mature_cum_sum=x['cnt_instalment_mature_cum_sum'],
        cnt_instalment_mature_cum_var=x['cnt_instalment_mature_cum_var'],
        cnt_instalment_mature_cum_std=x['cnt_instalment_mature_cum_std'],
        sk_dpd_max=x['sk_dpd_max'],
        sk_dpd_min=x['sk_dpd_min'],
        sk_dpd_mean=x['sk_dpd_mean'],
        sk_dpd_median=x['sk_dpd_median'],
        sk_dpd_sum=x['sk_dpd_sum'],
        sk_dpd_var=x['sk_dpd_var'],
        sk_dpd_std=x['sk_dpd_std'],
        sk_dpd_def_max=x['sk_dpd_def_max'],
        sk_dpd_def_min=x['sk_dpd_def_min'],
        sk_dpd_def_mean=x['sk_dpd_def_mean'],
        sk_dpd_def_median=x['sk_dpd_def_median'],
        sk_dpd_def_sum=x['sk_dpd_def_sum'],
        sk_dpd_def_var=x['sk_dpd_def_var'],
        sk_dpd_def_std=x['sk_dpd_def_std'],
        amt_balance_max_diff_3m=x['amt_balance_max_diff_3m'],
        amt_balance_min_diff_3m=x['amt_balance_min_diff_3m'],
        amt_balance_mean_diff_3m=x['amt_balance_mean_diff_3m'],
        amt_balance_median_diff_3m=x['amt_balance_median_diff_3m'],
        amt_balance_sum_diff_3m=x['amt_balance_sum_diff_3m'],
        amt_balance_var_diff_3m=x['amt_balance_var_diff_3m'],
        amt_balance_std_diff_3m=x['amt_balance_std_diff_3m'],
        amt_credit_limit_actual_max_diff_3m=x['amt_credit_limit_actual_max_diff_3m'],
        amt_credit_limit_actual_min_diff_3m=x['amt_credit_limit_actual_min_diff_3m'],
        amt_credit_limit_actual_mean_diff_3m=x['amt_credit_limit_actual_mean_diff_3m'],
        amt_credit_limit_actual_median_diff_3m=x['amt_credit_limit_actual_median_diff_3m'],
        amt_credit_limit_actual_sum_diff_3m=x['amt_credit_limit_actual_sum_diff_3m'],
        amt_credit_limit_actual_var_diff_3m=x['amt_credit_limit_actual_var_diff_3m'],
        amt_credit_limit_actual_std_diff_3m=x['amt_credit_limit_actual_std_diff_3m'],
        amt_drawings_atm_current_max_diff_3m=x['amt_drawings_atm_current_max_diff_3m'],
        amt_drawings_atm_current_min_diff_3m=x['amt_drawings_atm_current_min_diff_3m'],
        amt_drawings_atm_current_mean_diff_3m=x['amt_drawings_atm_current_mean_diff_3m'],
        amt_drawings_atm_current_median_diff_3m=x['amt_drawings_atm_current_median_diff_3m'],
        amt_drawings_atm_current_sum_diff_3m=x['amt_drawings_atm_current_sum_diff_3m'],
        amt_drawings_atm_current_var_diff_3m=x['amt_drawings_atm_current_var_diff_3m'],
        amt_drawings_atm_current_std_diff_3m=x['amt_drawings_atm_current_std_diff_3m'],
        amt_drawings_current_max_diff_3m=x['amt_drawings_current_max_diff_3m'],
        amt_drawings_current_min_diff_3m=x['amt_drawings_current_min_diff_3m'],
        amt_drawings_current_mean_diff_3m=x['amt_drawings_current_mean_diff_3m'],
        amt_drawings_current_median_diff_3m=x['amt_drawings_current_median_diff_3m'],
        amt_drawings_current_sum_diff_3m=x['amt_drawings_current_sum_diff_3m'],
        amt_drawings_current_var_diff_3m=x['amt_drawings_current_var_diff_3m'],
        amt_drawings_current_std_diff_3m=x['amt_drawings_current_std_diff_3m'],
        amt_drawings_other_current_max_diff_3m=x['amt_drawings_other_current_max_diff_3m'],
        amt_drawings_other_current_min_diff_3m=x['amt_drawings_other_current_min_diff_3m'],
        amt_drawings_other_current_mean_diff_3m=x['amt_drawings_other_current_mean_diff_3m'],
        amt_drawings_other_current_median_diff_3m=x['amt_drawings_other_current_median_diff_3m'],
        amt_drawings_other_current_sum_diff_3m=x['amt_drawings_other_current_sum_diff_3m'],
        amt_drawings_other_current_var_diff_3m=x['amt_drawings_other_current_var_diff_3m'],
        amt_drawings_other_current_std_diff_3m=x['amt_drawings_other_current_std_diff_3m'],
        amt_drawings_pos_current_max_diff_3m=x['amt_drawings_pos_current_max_diff_3m'],
        amt_drawings_pos_current_min_diff_3m=x['amt_drawings_pos_current_min_diff_3m'],
        amt_drawings_pos_current_mean_diff_3m=x['amt_drawings_pos_current_mean_diff_3m'],
        amt_drawings_pos_current_median_diff_3m=x['amt_drawings_pos_current_median_diff_3m'],
        amt_drawings_pos_current_sum_diff_3m=x['amt_drawings_pos_current_sum_diff_3m'],
        amt_drawings_pos_current_var_diff_3m=x['amt_drawings_pos_current_var_diff_3m'],
        amt_drawings_pos_current_std_diff_3m=x['amt_drawings_pos_current_std_diff_3m'],
        amt_inst_min_regularity_max_diff_3m=x['amt_inst_min_regularity_max_diff_3m'],
        amt_inst_min_regularity_min_diff_3m=x['amt_inst_min_regularity_min_diff_3m'],
        amt_inst_min_regularity_mean_diff_3m=x['amt_inst_min_regularity_mean_diff_3m'],
        amt_inst_min_regularity_median_diff_3m=x['amt_inst_min_regularity_median_diff_3m'],
        amt_inst_min_regularity_sum_diff_3m=x['amt_inst_min_regularity_sum_diff_3m'],
        amt_inst_min_regularity_var_diff_3m=x['amt_inst_min_regularity_var_diff_3m'],
        amt_inst_min_regularity_std_diff_3m=x['amt_inst_min_regularity_std_diff_3m'],
        amt_payment_current_max_diff_3m=x['amt_payment_current_max_diff_3m'],
        amt_payment_current_min_diff_3m=x['amt_payment_current_min_diff_3m'],
        amt_payment_current_mean_diff_3m=x['amt_payment_current_mean_diff_3m'],
        amt_payment_current_median_diff_3m=x['amt_payment_current_median_diff_3m'],
        amt_payment_current_sum_diff_3m=x['amt_payment_current_sum_diff_3m'],
        amt_payment_current_var_diff_3m=x['amt_payment_current_var_diff_3m'],
        amt_payment_current_std_diff_3m=x['amt_payment_current_std_diff_3m'],
        amt_payment_total_current_max_diff_3m=x['amt_payment_total_current_max_diff_3m'],
        amt_payment_total_current_min_diff_3m=x['amt_payment_total_current_min_diff_3m'],
        amt_payment_total_current_mean_diff_3m=x['amt_payment_total_current_mean_diff_3m'],
        amt_payment_total_current_median_diff_3m=x['amt_payment_total_current_median_diff_3m'],
        amt_payment_total_current_sum_diff_3m=x['amt_payment_total_current_sum_diff_3m'],
        amt_payment_total_current_var_diff_3m=x['amt_payment_total_current_var_diff_3m'],
        amt_payment_total_current_std_diff_3m=x['amt_payment_total_current_std_diff_3m'],
        amt_receivable_principal_max_diff_3m=x['amt_receivable_principal_max_diff_3m'],
        amt_receivable_principal_min_diff_3m=x['amt_receivable_principal_min_diff_3m'],
        amt_receivable_principal_mean_diff_3m=x['amt_receivable_principal_mean_diff_3m'],
        amt_receivable_principal_median_diff_3m=x['amt_receivable_principal_median_diff_3m'],
        amt_receivable_principal_sum_diff_3m=x['amt_receivable_principal_sum_diff_3m'],
        amt_receivable_principal_var_diff_3m=x['amt_receivable_principal_var_diff_3m'],
        amt_receivable_principal_std_diff_3m=x['amt_receivable_principal_std_diff_3m'],
        amt_recivable_max_diff_3m=x['amt_recivable_max_diff_3m'],
        amt_recivable_min_diff_3m=x['amt_recivable_min_diff_3m'],
        amt_recivable_mean_diff_3m=x['amt_recivable_mean_diff_3m'],
        amt_recivable_median_diff_3m=x['amt_recivable_median_diff_3m'],
        amt_recivable_sum_diff_3m=x['amt_recivable_sum_diff_3m'],
        amt_recivable_var_diff_3m=x['amt_recivable_var_diff_3m'],
        amt_recivable_std_diff_3m=x['amt_recivable_std_diff_3m'],
        amt_total_receivable_max_diff_3m=x['amt_total_receivable_max_diff_3m'],
        amt_total_receivable_min_diff_3m=x['amt_total_receivable_min_diff_3m'],
        amt_total_receivable_mean_diff_3m=x['amt_total_receivable_mean_diff_3m'],
        amt_total_receivable_median_diff_3m=x['amt_total_receivable_median_diff_3m'],
        amt_total_receivable_sum_diff_3m=x['amt_total_receivable_sum_diff_3m'],
        amt_total_receivable_var_diff_3m=x['amt_total_receivable_var_diff_3m'],
        amt_total_receivable_std_diff_3m=x['amt_total_receivable_std_diff_3m'],
        cnt_drawings_atm_current_max_diff_3m=x['cnt_drawings_atm_current_max_diff_3m'],
        cnt_drawings_atm_current_min_diff_3m=x['cnt_drawings_atm_current_min_diff_3m'],
        cnt_drawings_atm_current_mean_diff_3m=x['cnt_drawings_atm_current_mean_diff_3m'],
        cnt_drawings_atm_current_median_diff_3m=x['cnt_drawings_atm_current_median_diff_3m'],
        cnt_drawings_atm_current_sum_diff_3m=x['cnt_drawings_atm_current_sum_diff_3m'],
        cnt_drawings_atm_current_var_diff_3m=x['cnt_drawings_atm_current_var_diff_3m'],
        cnt_drawings_atm_current_std_diff_3m=x['cnt_drawings_atm_current_std_diff_3m'],
        cnt_drawings_current_max_diff_3m=x['cnt_drawings_current_max_diff_3m'],
        cnt_drawings_current_min_diff_3m=x['cnt_drawings_current_min_diff_3m'],
        cnt_drawings_current_mean_diff_3m=x['cnt_drawings_current_mean_diff_3m'],
        cnt_drawings_current_median_diff_3m=x['cnt_drawings_current_median_diff_3m'],
        cnt_drawings_current_sum_diff_3m=x['cnt_drawings_current_sum_diff_3m'],
        cnt_drawings_current_var_diff_3m=x['cnt_drawings_current_var_diff_3m'],
        cnt_drawings_current_std_diff_3m=x['cnt_drawings_current_std_diff_3m'],
        cnt_drawings_other_current_max_diff_3m=x['cnt_drawings_other_current_max_diff_3m'],
        cnt_drawings_other_current_min_diff_3m=x['cnt_drawings_other_current_min_diff_3m'],
        cnt_drawings_other_current_mean_diff_3m=x['cnt_drawings_other_current_mean_diff_3m'],
        cnt_drawings_other_current_median_diff_3m=x['cnt_drawings_other_current_median_diff_3m'],
        cnt_drawings_other_current_sum_diff_3m=x['cnt_drawings_other_current_sum_diff_3m'],
        cnt_drawings_other_current_var_diff_3m=x['cnt_drawings_other_current_var_diff_3m'],
        cnt_drawings_other_current_std_diff_3m=x['cnt_drawings_other_current_std_diff_3m'],
        cnt_drawings_pos_current_max_diff_3m=x['cnt_drawings_pos_current_max_diff_3m'],
        cnt_drawings_pos_current_min_diff_3m=x['cnt_drawings_pos_current_min_diff_3m'],
        cnt_drawings_pos_current_mean_diff_3m=x['cnt_drawings_pos_current_mean_diff_3m'],
        cnt_drawings_pos_current_median_diff_3m=x['cnt_drawings_pos_current_median_diff_3m'],
        cnt_drawings_pos_current_sum_diff_3m=x['cnt_drawings_pos_current_sum_diff_3m'],
        cnt_drawings_pos_current_var_diff_3m=x['cnt_drawings_pos_current_var_diff_3m'],
        cnt_drawings_pos_current_std_diff_3m=x['cnt_drawings_pos_current_std_diff_3m'],
        cnt_instalment_mature_cum_max_diff_3m=x['cnt_instalment_mature_cum_max_diff_3m'],
        cnt_instalment_mature_cum_min_diff_3m=x['cnt_instalment_mature_cum_min_diff_3m'],
        cnt_instalment_mature_cum_mean_diff_3m=x['cnt_instalment_mature_cum_mean_diff_3m'],
        cnt_instalment_mature_cum_median_diff_3m=x['cnt_instalment_mature_cum_median_diff_3m'],
        cnt_instalment_mature_cum_sum_diff_3m=x['cnt_instalment_mature_cum_sum_diff_3m'],
        cnt_instalment_mature_cum_var_diff_3m=x['cnt_instalment_mature_cum_var_diff_3m'],
        cnt_instalment_mature_cum_std_diff_3m=x['cnt_instalment_mature_cum_std_diff_3m'],
        sk_dpd_max_diff_3m=x['sk_dpd_max_diff_3m'],
        sk_dpd_min_diff_3m=x['sk_dpd_min_diff_3m'],
        sk_dpd_mean_diff_3m=x['sk_dpd_mean_diff_3m'],
        sk_dpd_median_diff_3m=x['sk_dpd_median_diff_3m'],
        sk_dpd_sum_diff_3m=x['sk_dpd_sum_diff_3m'],
        sk_dpd_var_diff_3m=x['sk_dpd_var_diff_3m'],
        sk_dpd_std_diff_3m=x['sk_dpd_std_diff_3m'],
        sk_dpd_def_max_diff_3m=x['sk_dpd_def_max_diff_3m'],
        sk_dpd_def_min_diff_3m=x['sk_dpd_def_min_diff_3m'],
        sk_dpd_def_mean_diff_3m=x['sk_dpd_def_mean_diff_3m'],
        sk_dpd_def_median_diff_3m=x['sk_dpd_def_median_diff_3m'],
        sk_dpd_def_sum_diff_3m=x['sk_dpd_def_sum_diff_3m'],
        sk_dpd_def_var_diff_3m=x['sk_dpd_def_var_diff_3m'],
        sk_dpd_def_std_diff_3m=x['sk_dpd_def_std_diff_3m'],
        flag_full_info_house=x['flag_full_info_house'],
        flag_delay_change_doc=x['flag_delay_change_doc'],
        ),
    ), axis=1)
df_test['TARGET'] = df_test['result'].apply(lambda x: x.proba)

# %%
submission = df_test[['SK_ID_CURR', 'TARGET']]
submission = submission.sort_values(by='SK_ID_CURR').reset_index(drop=True)
submission.to_csv('submission_add_features.csv', index=False)

# %% [markdown]
# ![score](score_add_features.jpg)

# %% [markdown]
# ![score](score.jpg)
